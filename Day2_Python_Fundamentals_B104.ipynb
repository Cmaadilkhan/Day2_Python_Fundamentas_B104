# %%
There  will be no session recording, only live.
All of you must maintain running notes, with notebook and pen.
# Out:
#   Cell In[1], line 1
#     There  will be no session recording, only live.
#            ^
# SyntaxError: invalid syntax

# %%
Introduction to Python Programming :

# %%
Understanding the concept of variables :

# %%
a = 2
b = 3

c = a+b

print(c)
# Out:
# 5

# %%
Rules for declaring the Variables in python :

# %%
Rule No1 : No namespaces while declaring the variable

# %%
first name = 'Faiyaz'

print(first name)
# Out:
#   Cell In[3], line 1
#     first name = 'Faiyaz'
#           ^
# SyntaxError: invalid syntax

# %%
firstname = 'Faiyaz'

print(firstname)
# Out:
# Faiyaz

# %%
Rule No2 : A Variable name should not start with a number.**

# %%
1name = 'Dinesh'

print(1name)
# Out:
#   Cell In[5], line 1
#     1name = 'Dinesh'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'Dinesh'

print(name1)
# Out:
# Dinesh

# %%
Rule No3 : A Variable name should not contain any Special Characters
          
    @ # $ % & *

# %%
name@ = 'sanvika'

print(name@)
# Out:
#   Cell In[7], line 1
#     name@ = 'sanvika'
#           ^
# SyntaxError: invalid syntax

# %%
Introduction to Datatypes in python :
1. Strings ---> str
2. Numbers ---> integers (int) and float (decimals)
3. Lists ---> list4
4. tuple ---> tuple
5. Dictionaries ---> dict

# %%
Classification of datatypes :
Broadly datatypes are classified in to 2 different Categories
1. Mutable Datatype ---> where we can edit or modify the data --> flexible in nature
2. Immutable Datatype ---> where we can not edit or modify the data --> fixed in nature

# %%
Introduction to String datatype :
Definition : A String is nothing but a series of characters declared in quotes.

Classification : It is classifed as an immutable datatype.

How to declare the string ---? single quote and double quote

# %%
name = 'rahul' # single quote

print(name)
# Out:
# rahul

# %%
name2 = "Asmitha" # double quote

print(name2)
# Out:
# Asmitha

# %%
#Introduction to String methods

# %%
Before putting # sign in the beginning jypyter will consider it as a Comment

# %%
How to identify a variable, what kind of data type it is....?
    
name2 ---> i want to understand what kind of datatype it is...?

# %%
type(name2)
# Out:
# str

# %%
type(name)
# Out:
# str

# %%
_type(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 _type(name)
#
# NameError: name '_type' is not defined

# %%
 type(name)
# Out:
# str
